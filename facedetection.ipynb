# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img=plt.imread("/content/photophoto.jpg")

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (500, 700, 3)

# %%
import cv2

# %%
model=cv2.CascadeClassifier("/content/haarcascade_frontalface_alt.xml")

# %%
faces=model.detectMultiScale(img)

# %%
faces
# Out:
# array([[327, 143,  68,  68],
#        [464, 148,  74,  74],
#        [175, 131,  76,  76],
#        [271, 133,  71,  71],
#        [396, 154,  75,  75]], dtype=int32)

# %%
faces.shape
# Out:
# (5, 4)

# %%
temp=0
for face in faces:
  x,y,w,h=face
  temp+=1



  cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,0),2)

# %%
plt.imshow(img)

# %%
print(temp)
# Out:
# 5
